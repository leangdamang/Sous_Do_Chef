# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import nltk, string

from collections import defaultdict
from pymongo import MongoClient
from textblob import TextBlob 
from nltk.corpus import stopwords
from sklearn.externals import joblib 
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity

pd.options.display.max_rows = 20
pd.options.display.max_columns = 20

# %matplotlib inline

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

def get_top_words(model, feature_names, n_top_words):
    message = {}
    for topic_idx, topic in enumerate(model.components_):
        message[topic_idx] = (" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    return message

def get_sub_category_names(topic, df, column, tfmodel, components): 
    """run the subtopic modeling, get the top words for each subtopic, 
    assign it to a dictionary with the key being the get_topics value"""
    dictionary = defaultdict(int) 
    df_new = df[df['topic']==topic]
    cat0 = tfmodel.transform(df_new[column])
    nmfnew = NMF(n_components = components).fit(cat0) #this runs the subtopic model
    subtopics = get_top_words(nmfnew, tfmodel.get_feature_names(), 3)
    for index, x in enumerate(subtopics):
        dictionary [index+ topic*components] = x
    return dictionary

def get_sub_category(topic, df, column, tfmodel, components):
    df_new = df[df['topic']==topic]
    cat0 = tfmodel.transform(df_new[column])
    nmfnew = NMF(n_components = components).fit(cat0)
    print_top_words(nmfnew, tfmodel.get_feature_names(), 10)
    df_new['subcategory'] = get_topics(nmfnew, cat0, topic, components)
    return df_new
    
def get_topics(NMFmodel, TFIDF, topic, components):
    nmf = NMFmodel.transform(TFIDF)
    topics = []
    for x in nmf:
        topics.append(np.argmax(x)+(topic*components))
    return topics

# %%
df = pd.read_pickle('df_posts') #Primary DataFrame, 25 topics
nmffit = joblib.load('nmffit') #Fitted TF-IDF vectors onto NMF model
tfmodel = joblib.load('tfmodel') #TF-IDF model 
tfvectors = joblib.load('tfvectors') #TF-IDF matrix

# %%
tfvectors
# Out:
# <36388x270552 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2130600 stored elements in Compressed Sparse Row format>

# %%
cat0 = tfmodel.transform(df[df['topic']==0]['question'])

# %%
nmfnew = NMF(n_components = 5).fit(cat0)

# %%
print_top_words(nmffit, tfmodel.get_feature_names(), 10)
# Out:
# Topic #0: time first salt water best little used ingredients butter suggestions
# Topic #1: chicken breast breasts chicken breast fried chicken chicken breasts fried stock thighs chicken stock
# Topic #2: iron cast cast iron skillet iron skillet iron pan seasoning skillets lodge seasoned
# Topic #3: rice rice cooker fried rice cooker brown rice fried white rice water white brown
# Topic #4: pork pulled pork pulled belly pork belly shoulder pork shoulder chops pork chops fat
# Topic #5: oil olive olive oil garlic frying canola oils deep vegetable oil salt
# Topic #6: cream ice ice cream heavy heavy cream whipped whipped cream chocolate cream maker maker
# Topic #7: sauce tomato tomato sauce soy soy sauce hot sauce hot tomatoes garlic sauces
# Topic #8: pizza dough pizza dough bread flour stone yeast crust pizza stone homemade pizza
# Topic #9: beef ground ground beef stew beef stew corned roast corned beef cut wellington
# Topic #10: cheese mac mac cheese cheese sauce cheddar cream cheese macaroni cheeses macaroni cheese cream
# Topic #11: knife knives chef chef knife sharpening set sharpener steel sharpen kitchen
# Topic #12: meat cut cooked thermometer cut meat cuts lamb grinder vegetarian fat
# Topic #13: eggs egg scrambled whites scrambled eggs yolk yolks breakfast boiled egg whites
# Topic #14: oven dutch dutch oven stove roast convection temperature ribs baking microwave
# Topic #15: pasta pasta sauce fresh pasta water pasta water homemade pasta spaghetti noodles pasta dish fresh
# Topic #16: cooker slow slow cooker pressure pressure cooker rice cooker pot crock hours crock pot
# Topic #17: sous vide sous vide steak steaks rare sear temperature medium rare medium
# Topic #18: soup stock broth bones onion onion soup chicken stock soups noodle french onion
# Topic #19: beans chili black black beans bean dried canned kidney green green beans
# Topic #20: potatoes potato mashed sweet mashed potatoes sweet potato sweet potatoes baked roasted fries
# Topic #21: pan steel stainless stainless steel pans stick non stick non heat frying
# Topic #22: turkey thanksgiving brine bird brining year ground turkey turkey breast breast dry
# Topic #23: fish salmon fish sauce sushi fish tacos seafood cod tacos fish chips frozen
# Topic #24: milk coconut curry coconut milk thai paste curry paste powder thai curry coconut oil

# %%
df_test = get_sub_category(0, df, 'question', tfmodel, 5)
df_test = df_test.append(get_sub_category(1, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(2, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(3, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(4, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(5, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(6, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(7, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(8, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(9, df, 'question', tfmodel, 5))
# Out:
# Topic #0: garlic salt fresh pepper taste spices onion onions flavor wine
# Topic #1: sugar butter baking flour bread cup soda pie water powder
# Topic #2: chocolate cake cookies chocolate cake chocolate chip chip cocoa birthday mousse white chocolate
# Topic #3: kitchen time new meals love home meal suggestions dishes dinner
# Topic #4: favorite cookbook favorite cookbook pumpkin favorite thing love shows pie new share favorite
# /Users/leangchaing/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Topic #0: chicken breast chicken breast roast chicken cooked roast sauce marinade time whole
# Topic #1: fried chicken fried chicken buttermilk breading brine fry flour frying chicken buttermilk
# Topic #2: stock chicken stock chicken bones whole chicken fat whole broth carcass stock chicken
# Topic #3: breasts chicken breasts chicken boneless skinless marinate frozen chicken marinate chicken frozen boneless skinless
# Topic #4: thighs chicken thighs wings chicken chicken wings skin boneless bone buffalo best
#
# Topic #0: iron cast cast iron pans skillets iron skillets iron pans iron cookware cookware season
# Topic #1: skillet iron skillet cast cast iron iron steak seasoned steaks oven 12
# Topic #2: pan iron pan iron cast cast iron steak oil seasoning grill seasoned
# Topic #3: steel wok carbon steel carbon iron stainless cast cast iron stainless steel pans
# Topic #4: dutch dutch oven enameled oven cast iron cast iron dutch iron enameled cast pot
#
# Topic #0: rice water cooked sticky grain white rice basmati rice rice time cooked rice
# Topic #1: rice cooker cooker rice cooker rice rice rice cookers rice cookers cup water oats rice
# Topic #2: fried rice fried rice soy sauce chicken wok soy sauce chinese chicken fried
# Topic #3: brown rice rice brown white rice white rice brown rice white rice salad eating grain brown
# Topic #4: vinegar rice vinegar rice wine sushi wine rice wine vinegar sushi rice white vinegar rice
#
# Topic #0: pulled pork pulled pork bbq slow sauce butt bbq sauce sides pulled crock
# Topic #1: belly pork belly pork skin braised pork crispy fat braised hours slab
# Topic #2: chops pork chops pork pork chop chop sweet sour sour peppers sour risotto chops sweet
# Topic #3: shoulder pork shoulder pork slow fat meat hours skin roast cut
# Topic #4: pork loin pork loin roast tenderloin fat pork tenderloin cut meat ribs
#
# Topic #0: oil canola vegetable oil oils canola oil smoke vegetable coconut oil pan peanut
# Topic #1: olive olive oil oil extra virgin virgin virgin olive extra oils evoo bottle
# Topic #2: deep deep frying frying fryer deep fryer oil oil deep deep fry fry fried
# Topic #3: garlic salt pepper vinegar dressing oil garlic oil salt pepper chopped minutes
# Topic #4: board cutting mineral oil mineral cutting board oil boards wood cutting boards end grain
#
# Topic #0: ice ice cream cream cream maker maker vanilla machine cream machine frozen freezer
# Topic #1: cream heavy heavy cream whipping whipping cream heavy whipping milk butter cream heavy fat
# Topic #2: whipped whipped cream cream whip cream whipped cake stabilized whipped stabilized pie mascarpone
# Topic #3: sour cream sour cream yogurt buttermilk greek creme cream cheese creme fraiche fraiche
# Topic #4: chocolate cake butter chocolate cake vanilla mousse layer sugar frosting cream
#
# Topic #0: sauce spaghetti spaghetti sauce garlic wine chicken red sauces butter dish
# Topic #1: tomato tomato sauce tomatoes sauce tomato paste paste canned fresh canned tomatoes canned tomato
# Topic #2: hot sauce hot sauce peppers wing wings sauces hot sauces wing sauce sauce hot
# Topic #3: soy soy sauce sauce stir asian stir fry chinese sesame fry salty
# Topic #4: bbq bbq sauce sauce mustard ketchup barbecue barbecue sauce vinegar sweet ribs
#
# Topic #0: pizza homemade pizza pizza dough homemade sauce pizza sauce crust pizzas oven cheese
# Topic #1: dough pizza dough rise knead pie fridge flour kneading mixer cookie
# Topic #2: bread bread machine bread dough machine loaf bread maker sourdough maker rise starter
# Topic #3: yeast flour rise water dry yeast active instant yeast instant active dry salt
# Topic #4: stone pizza stone pizza clean pizza clean best clean stone pizza recommend pizza bought pizza baking
#
# Topic #0: beef roast cut meat cut beef roast beef tender jerky cuts stock
# Topic #1: ground ground beef beef burgers lean chili meat burger tacos browning
# Topic #2: corned corned beef beef cabbage beef cabbage brisket st beef brisket curing brown corned
# Topic #3: stew beef stew beef stew meat meat wine pot crock crock pot red wine
# Topic #4: wellington beef wellington beef christmas wellington christmas pastry first tenderloin puff wellington first

# %%
df_test = df_test.append(get_sub_category(10, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(11, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(12, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(13, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(14, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(15, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(16, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(17, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(18, df, 'question', tfmodel, 5))
df_test = df_test.append(get_sub_category(19, df, 'question', tfmodel, 5))
# Out:
# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36388 entries, 1 to 36365
# Data columns (total 8 columns):
# date              36388 non-null datetime64[ns]
# score             36388 non-null int64
# second_comment    36388 non-null object
# top_comment       36388 non-null object
# question          36388 non-null object
# log_score         36388 non-null float64
# topic             36388 non-null int64
# subcategory       36388 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 2.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36388 entries, 0 to 36387
# Data columns (total 7 columns):
# date              36388 non-null datetime64[ns]
# score             36388 non-null int64
# second_comment    36388 non-null object
# top_comment       36388 non-null object
# question          36388 non-null object
# log_score         36388 non-null float64
# topic             36388 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df_test[df_test['topic'] == 1]
# Out:
#                      date  score  \
# 2     2017-08-13 22:48:13     17
# 15    2017-08-13 04:10:24     21
# 25    2017-08-12 19:04:43    409
# 41    2017-08-12 00:52:03     23
# 45    2017-08-11 18:01:24     54
# 53    2017-08-11 05:11:32     67
# 75    2017-08-10 02:44:25     24
# 86    2017-08-09 19:40:31     12
# 97    2017-08-08 14:04:49      7
# 98    2017-08-08 08:52:50     14
# ...                   ...    ...
# 36151 2014-12-08 18:07:59     10
# 36189 2014-12-07 06:51:43    104
# 36222 2014-12-06 07:52:19      5
# 36226 2014-12-06 05:24:56     12
# 36273 2014-12-05 01:08:45      5
# 36345 2014-12-02 16:12:20     11
# 36346 2014-12-02 15:27:50     83
# 36359 2014-12-02 03:02:29     51
# 36375 2014-12-01 22:13:18    120
# 36380 2014-12-01 19:47:52     55
#
#                                           second_comment  \
# 2      Even when vanilla isn't accompanied by sugar, ...
# 15     Tyler Florence has a good video\n\nhttp://www....
# 25     Not saying you should roast a whole chicken, b...
# 41     Just here to back up the other comments: bakin...
# 45     Just brainstorming here, would halving the pin...
# 53     If this dish seems to be common in London, you...
# 75     Shred and put in salad, burritos tacos and que...
# 86     Marinade is good. It almost doesn't matter how...
# 97     Chicken is typically far cheaper so it's less ...
# 98     I asked something similar about a year ago.  I...
# ...                                                  ...
# 36151  In theory, these should last longer than a wee...
# 36189                                    Yum.  Will try.
# 36222                       What temp is your fridge at?
# 36226  It sounds weird, but I make a creamy chipotle ...
# 36273  How special your capons are depends on where a...
# 36345  Just wash it as normal. Disinfect with some De...
# 36346  Fenugreek!\nI use this recipe but add more but...
# 36359                                          [deleted]
# 36375  My experience is pressure cooking gets you a m...
# 36380  Roasted veggie and black bean burritos: http:/...
#
#                                              top_comment  \
# 2      yep. you could try to mask it, but honestly no...
# 15     Check with Julia Childs, she had that one on l...
# 25      When my wife is gone for the evening I get dr...
# 41     First off, pat dry the chicken with paper towe...
# 45     Chicken?  Why chicken? \n\nI'd use a pork loin...
# 53     Maybe it is a variation on dak galbi, with a g...
# 75     This won't earn me bonus points but I like to ...
# 86     Totally! I work at a restaurant in Montana. an...
# 97     Well, for one - Venison costs a lot more than ...
# 98     The best butter chicken that I've tried to dat...
# ...                                                  ...
# 36151  After browsing the recipe & comments they say ...
# 36189  I made almost this exact same thing last night...
# 36222  How are you reheating it (if you are heating a...
# 36226  This recipe looked pretty good. \nhttp://thepi...
# 36273  Capons don't need any special technique in the...
# 36345  Salmonella and other bacteria can't live on a ...
# 36346  I'm Indian :) \n\nWell this is tough without s...
# 36359  Southern staple side dish: rice with pan dripp...
# 36375  Other commenters offered viable techniques, I'...
# 36380  Lasagna! Don't over do it with watery vegetabl...
#
#                                                 question  log_score  topic  \
# 2      Vanilla yogurt in chicken tandoori I'm in the ...   2.833213      1
# 15     My mother wishes to cook a chicken cordon bleu...   3.044522      1
# 25     What do you cook when you're dining alone? Wif...   6.013715      1
# 41     How to get a lot of batter to stick to chicken...   3.135494      1
# 45     Lets talk about baking a pineapple I want to h...   3.988984      1
# 53     Spicy chicken street food from a stall in Lond...   4.204693      1
# 75     Leftover cooked chicken breast, easy uses? Tit...   3.178054      1
# 86     Can a buttermilk marinade be used to make chic...   2.484907      1
# 97     Why, when you are looking at a recipe for veni...   1.945910      1
# 98     Looking for your favourite Butter Chicken reci...   2.639057      1
# ...                                                  ...        ...    ...
# 36151  How long does home-made pâté keep? Can I can i...   2.302585      1
# 36189  Parmesan and panko crusted chicken breast with...   4.644391      1
# 36222  Any advice on keeping cooked chicken tasting f...   1.609438      1
# 36226  Lots of plain Greek Yogurt I don't know what t...   2.484907      1
# 36273  I got a couple of capons as a gift and I was t...   1.609438      1
# 36345  Forgot cleaning cutting board from raw chicken...   2.397895      1
# 36346  Butter Chicken not tasting "authentic" or "res...   4.418841      1
# 36359  Made some chicken thighs marinated in yogurt i...   3.931826      1
# 36375  How to cook shredded chicken for tacos The Mex...   4.787492      1
# 36380  What are your best freeze and reheat meals? Bo...   4.007333      1
#
#        subcategory
# 2                5
# 15               5
# 25               5
# 41               5
# 45               5
# 53               5
# 75               5
# 86               6
# 97               5
# 98               5
# ...            ...
# 36151            5
# 36189            5
# 36222            5
# 36226            5
# 36273            5
# 36345            5
# 36346            5
# 36359            9
# 36375            5
# 36380            5
#
# [1742 rows x 8 columns]

# %%
subtopiclabels = get_sub_category_names(0, df, 'question', tfmodel, 5)
subtopiclabels.update(get_sub_category_names(1, df, 'question', tfmodel, 5))

# %%
for x in range(2,25):
    subtopiclabels.update(get_sub_category_names(x, df, 'question', tfmodel, 5))

# %%
topiclabels = get_top_words(nmffit, tfmodel.get_feature_names(), 5)

# %%
topiclabels
# Out:
# {0: 'time first salt water best',
#  1: 'chicken breast breasts chicken breast fried chicken',
#  2: 'iron cast cast iron skillet iron skillet',
#  3: 'rice rice cooker fried rice cooker brown rice',
#  4: 'pork pulled pork pulled belly pork belly',
#  5: 'oil olive olive oil garlic frying',
#  6: 'cream ice ice cream heavy heavy cream',
#  7: 'sauce tomato tomato sauce soy soy sauce',
#  8: 'pizza dough pizza dough bread flour',
#  9: 'beef ground ground beef stew beef stew',
#  10: 'cheese mac mac cheese cheese sauce cheddar',
#  11: 'knife knives chef chef knife sharpening',
#  12: 'meat cut cooked thermometer cut meat',
#  13: 'eggs egg scrambled whites scrambled eggs',
#  14: 'oven dutch dutch oven stove roast',
#  15: 'pasta pasta sauce fresh pasta water pasta water',
#  16: 'cooker slow slow cooker pressure pressure cooker',
#  17: 'sous vide sous vide steak steaks',
#  18: 'soup stock broth bones onion',
#  19: 'beans chili black black beans bean',
#  20: 'potatoes potato mashed sweet mashed potatoes',
#  21: 'pan steel stainless stainless steel pans',
#  22: 'turkey thanksgiving brine bird brining',
#  23: 'fish salmon fish sauce sushi fish tacos',
#  24: 'milk coconut curry coconut milk thai'}

# %%
df_categories = df_test.groupby(['topic','subcategory'])['score'].agg(['size', 'sum']).reset_index()

# %%
df_categories['subcategory'] = df_categories['subcategory'].replace(subtopiclabels)

# %%
df_categories['topic'] = df_categories['topic'].replace(topiclabels)

# %%
df_categories.tail(10)
# Out:
#                                        topic                     subcategory  \
# 115  fish salmon fish sauce sushi fish tacos             fish fish chips cod
# 116  fish salmon fish sauce sushi fish tacos       salmon smoked salmon skin
# 117  fish salmon fish sauce sushi fish tacos           fish sauce fish sauce
# 118  fish salmon fish sauce sushi fish tacos         sushi sushi grade grade
# 119  fish salmon fish sauce sushi fish tacos           tacos fish tacos fish
# 120     milk coconut curry coconut milk thai         milk almond almond milk
# 121     milk coconut curry coconut milk thai        curry paste curry powder
# 122     milk coconut curry coconut milk thai       coconut coconut milk milk
# 123     milk coconut curry coconut milk thai           thai thai curry paste
# 124     milk coconut curry coconut milk thai  chocolate milk chocolate cocoa
#
#      size    sum
# 115   434  20526
# 116   176   9173
# 117    48   2310
# 118    35   2814
# 119    34   1920
# 120   265  11096
# 121   185   8076
# 122   174   6277
# 123    63   4106
# 124    64   2089

# %%
lis = []
for topic in df_categories['topic'].unique():
    sub_list = []
    for sub in df_categories[df_categories['topic'] == topic]['subcategory']:  
        sub_list.append({"name" : sub, "size" : int(df_categories[df_categories['subcategory'] == sub]['size'])})
    lis.append({"name" : topic, "children" : sub_list})
topics = {'name' : 'Topics', 'children' : lis}

# %%
topics
# Out:
# {'children': [{'children': [{'name': 'time eat first', 'size': 3385},
#     {'name': 'sugar butter baking', 'size': 1934},
#     {'name': 'chocolate cake cookies', 'size': 553},
#     {'name': 'kitchen favorite new', 'size': 7700},
#     {'name': 'salt garlic pepper', 'size': 580}],
#    'name': 'time eat first meals dinner'},
#   {'children': [{'name': 'chicken breast chicken breast', 'size': 1066},
#     {'name': 'fried chicken fried chicken', 'size': 159},
#     {'name': 'stock chicken stock chicken', 'size': 162},
#     {'name': 'breasts chicken breasts chicken', 'size': 179},
#     {'name': 'thighs chicken thighs wings', 'size': 176}],
#    'name': 'sugar butter baking flour bread'},
#   {'children': [{'name': 'iron cast cast iron', 'size': 227},
#     {'name': 'skillet iron skillet cast', 'size': 182},
#     {'name': 'pan iron pan iron', 'size': 193},
#     {'name': 'steel wok carbon steel', 'size': 88},
#     {'name': 'dutch dutch oven enameled', 'size': 71}],
#    'name': 'chocolate cake cookies chocolate cake chocolate chip'},
#   {'children': [{'name': 'rice water cooked', 'size': 573},
#     {'name': 'rice cooker cooker rice', 'size': 119},
#     {'name': 'fried rice fried rice', 'size': 122},
#     {'name': 'brown rice rice brown', 'size': 68},
#     {'name': 'vinegar rice vinegar rice wine', 'size': 46}],
#    'name': 'kitchen favorite new culinary learn'},
#   {'children': [{'name': 'pulled pork pulled pork', 'size': 132},
#     {'name': 'belly pork belly pork', 'size': 153},
#     {'name': 'chops pork chops pork', 'size': 104},
#     {'name': 'shoulder pork shoulder pork', 'size': 149},
#     {'name': 'pork loin pork loin', 'size': 517}],
#    'name': 'salt garlic pepper spices taste'},
#   {'children': [{'name': 'oil canola vegetable oil', 'size': 388},
#     {'name': 'olive olive oil oil', 'size': 330},
#     {'name': 'deep deep frying frying', 'size': 80},
#     {'name': 'garlic salt pepper', 'size': 216},
#     {'name': 'board cutting mineral oil', 'size': 30}],
#    'name': 5},
#   {'children': [{'name': 'ice ice cream cream', 'size': 332},
#     {'name': 'cream heavy heavy cream', 'size': 218},
#     {'name': 'whipped whipped cream cream', 'size': 75},
#     {'name': 'sour cream sour cream', 'size': 75},
#     {'name': 'chocolate cake butter', 'size': 101}],
#    'name': 6},
#   {'children': [{'name': 'sauce spaghetti spaghetti sauce', 'size': 791},
#     {'name': 'tomato tomato sauce tomatoes', 'size': 226},
#     {'name': 'hot sauce hot sauce', 'size': 148},
#     {'name': 'soy soy sauce sauce', 'size': 156},
#     {'name': 'bbq bbq sauce sauce', 'size': 94}],
#    'name': 7},
#   {'children': [{'name': 'pizza homemade pizza pizza dough', 'size': 292},
#     {'name': 'dough pizza dough rise', 'size': 303},
#     {'name': 'bread bread machine bread dough', 'size': 77},
#     {'name': 'yeast flour rise', 'size': 111},
#     {'name': 'stone pizza stone pizza', 'size': 45}],
#    'name': 8},
#   {'children': [{'name': 'beef roast cut', 'size': 606},
#     {'name': 'ground ground beef beef', 'size': 236},
#     {'name': 'corned corned beef beef', 'size': 75},
#     {'name': 'stew beef stew beef', 'size': 127},
#     {'name': 'wellington beef wellington beef', 'size': 60}],
#    'name': 9},
#   {'children': [{'name': 'cheese cheese sauce cheddar', 'size': 550},
#     {'name': 'mac mac cheese cheese', 'size': 184},
#     {'name': 'cream cheese cream cheese', 'size': 117},
#     {'name': 'goat goat cheese cheese', 'size': 50},
#     {'name': 'macaroni macaroni cheese cheese', 'size': 64}],
#    'name': 10},
#   {'children': [{'name': 'knife chef knife knife skills', 'size': 371},
#     {'name': 'knives set kitchen knives', 'size': 216},
#     {'name': 'sharpening sharpen stone', 'size': 76},
#     {'name': 'chef chef knife santoku', 'size': 133},
#     {'name': 'honing steel honing steel', 'size': 65}],
#    'name': 11},
#   {'children': [{'name': 'meat cut chicken', 'size': 838},
#     {'name': 'meat grinder grinder meat', 'size': 54},
#     {'name': 'thermometer meat thermometer meat', 'size': 36},
#     {'name': 'crab crab meat crab legs', 'size': 23},
#     {'name': 'vegetarian vegan meat', 'size': 53}],
#    'name': 12},
#   {'children': [{'name': 'eggs poached poached eggs', 'size': 454},
#     {'name': 'egg yolk egg yolk', 'size': 268},
#     {'name': 'boiled boiled eggs hard boiled', 'size': 66},
#     {'name': 'whites egg whites egg', 'size': 86},
#     {'name': 'scrambled scrambled eggs eggs', 'size': 99}],
#    'name': 13},
#   {'children': [{'name': 'oven temperature roast', 'size': 540},
#     {'name': 'dutch dutch oven oven', 'size': 203},
#     {'name': 'ribs ribs oven grill', 'size': 57},
#     {'name': 'stove gas electric', 'size': 111},
#     {'name': 'convection convection oven oven', 'size': 84}],
#    'name': 14},
#   {'children': [{'name': 'pasta sauce pasta sauce', 'size': 460},
#     {'name': 'pasta fresh pasta fresh', 'size': 133},
#     {'name': 'water pasta water pasta', 'size': 84},
#     {'name': 'lasagna homemade pasta homemade', 'size': 46},
#     {'name': 'olio aglio aglio olio', 'size': 27}],
#    'name': 15},
#   {'children': [{'name': 'slow cooker cooker slow', 'size': 254},
#     {'name': 'pressure pressure cooker cooker', 'size': 170},
#     {'name': 'roast pot roast pot', 'size': 28},
#     {'name': 'slow ribs slow cooked', 'size': 82},
#     {'name': 'pot crock crock pot', 'size': 36}],
#    'name': 16},
#   {'children': [{'name': 'sous vide sous vide', 'size': 349},
#     {'name': 'steak cut pan', 'size': 238},
#     {'name': 'rare medium rare medium', 'size': 42},
#     {'name': 'flank steak flank steak', 'size': 14},
#     {'name': 'steaks steak grill', 'size': 48}],
#    'name': 17},
#   {'children': [{'name': 'soup chicken soups', 'size': 598},
#     {'name': 'stock bones chicken stock', 'size': 203},
#     {'name': 'onion soup french onion onion', 'size': 53},
#     {'name': 'broth chicken noodle', 'size': 102},
#     {'name': 'mushroom mushroom soup cream mushroom', 'size': 39}],
#    'name': 18},
#   {'children': [{'name': 'beans dried dried beans', 'size': 306},
#     {'name': 'chili chili powder powder', 'size': 141},
#     {'name': 'black black beans bean', 'size': 103},
#     {'name': 'green beans green beans', 'size': 76},
#     {'name': 'refried refried beans beans', 'size': 38}],
#    'name': 19},
#   {'children': [{'name': 'potatoes roasted sweet potatoes', 'size': 338},
#     {'name': 'potato potato salad potato chips', 'size': 160},
#     {'name': 'mashed mashed potatoes potatoes', 'size': 160},
#     {'name': 'sweet sweet potato sweet potatoes', 'size': 133},
#     {'name': 'fries french fries french', 'size': 47}],
#    'name': 20},
#   {'children': [{'name': 'pan oil heat', 'size': 620},
#     {'name': 'steel stainless stainless steel', 'size': 191},
#     {'name': 'non stick non stick', 'size': 147},
#     {'name': 'pans pots pots pans', 'size': 168},
#     {'name': 'cookware clad set', 'size': 98}],
#    'name': 21},
#   {'children': [{'name': 'turkey bird oven', 'size': 289},
#     {'name': 'thanksgiving thanksgiving dinner year', 'size': 119},
#     {'name': 'brine brining dry brine', 'size': 73},
#     {'name': 'ground turkey turkey ground', 'size': 33},
#     {'name': 'turkey breast breast turkey', 'size': 36}],
#    'name': 22},
#   {'children': [{'name': 'fish fish chips cod', 'size': 434},
#     {'name': 'salmon smoked salmon skin', 'size': 176},
#     {'name': 'fish sauce fish sauce', 'size': 48},
#     {'name': 'sushi sushi grade grade', 'size': 35},
#     {'name': 'tacos fish tacos fish', 'size': 34}],
#    'name': 23},
#   {'children': [{'name': 'milk almond almond milk', 'size': 265},
#     {'name': 'curry paste curry powder', 'size': 185},
#     {'name': 'coconut coconut milk milk', 'size': 174},
#     {'name': 'thai thai curry paste', 'size': 63},
#     {'name': 'chocolate milk chocolate cocoa', 'size': 64}],
#    'name': 24}],
#  'name': 'Topics'}

# %%
import json

# %%
with open('topics.json', 'w') as f:
     json.dump(topics, f)

# %%
df_test.to_pickle('df_subcats')
